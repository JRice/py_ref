# %% [markdown]
# Talk about the challenge here...

# %%
import ipytest
ipytest.autoconfig()

def test_solution():
    assert True

ipytest.run()
# Out:
# .                                                                                            [100%]
# 1 passed in 0.14s
# <ExitCode.OK: 0>
